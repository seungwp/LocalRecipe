# %% [markdown]
# <a href="https://colab.research.google.com/github/seungwp/LocalRecipe/blob/main/AIF_P04_%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80_00%ED%8C%80_%EA%B2%B0%EA%B3%BC%EB%B3%B4%EA%B3%A0%EC%84%9C_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### AutoMPG 선형회귀 과제
#
# - 팀정보
#   - 팀번호: 01팀
#   - 참여팀원명:
#   - 불참팀원명:
#
#
# - Dataset: AutoMPG dataset
#   - 정답값: mpg
#   - 특징: origion을 제외한 6개의 특징들
#     - ['Cylinders','Displacement','Horsepower','Weight','Acceleration','Model Year']
# - Train : Test = 7 : 3
#
# (1) Data  정제: 누락된 특징은 그 특징의 평균값으로 대체하라.
# (2) 각 특징들과 mpg(정답값)사이의 상관계수를 구하고, Seaborn(SNS) 히트맵을 그려라.
#
# (3) 상관계수가 가장 높은 순서로 특징을 $x_1, x_2, ..., x_6$이라고 할 때,
# 특징1개(x1)만을 사용해서 선형회귀를 한 $R^2$ score  $S_1$을 구하라.
# 특징2개(x1, x2)를 사용해서 선형회귀를 한 $R^2$ score   $S_2$을 구하라.
# 이런 식으로 특징 6개를 사용한 s6를  구하라.
# 가로축은 특징의 개수, 세로축은 $S_1, ..., S_6$인 그래프를 그려라.
#
# (4) 특징을 6개 사용한 경우에 대해 Test dataset에 대해  정답값과 예측치간의 MSE를 구하기
#
# - $MSE = \frac{1}{N} \sum_{i=1}^{N} \left( y_i - \hat{y}_i \right)^2$
#
# 여기에서 $y_i$와 $\hat{y}_i$는 각각 정답값과 예측치를 의미함
#
# (5) 특징을 6개 사용한 경우 $x$축은 정답값($y_i$), $y$축은 예측치($\hat{y}_i$)인 그래프를 그려라.측치( y^i )인 그래프를 그려라.

# %%
# 평균값으로 누락된 특징이 정제된 AutoMPG dataset
import pathlib
import matplotlib.pyplot as plt
import pandas as pd

dataset_path='http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names=['MPG','Cylinders','Displacement','Horsepower','Weight','Acceleration','Model Year','Origin']
mpg_df=pd.read_csv(dataset_path,names=column_names, na_values='?',comment='\t', sep=' ',skipinitialspace=True)

mpg_df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
mpg_df.count()
# Out:
# MPG             398
# Cylinders       398
# Displacement    398
# Horsepower      392
# Weight          398
# Acceleration    398
# Model Year      398
# Origin          398
# dtype: int64

# %% [markdown]
# #### (1) Data 정제하기

# %%
missing_index = mpg_df['Horsepower'].isna()
print("1: Missing index")
print(missing_index[30:35])
mpg_df[missing_index]
# Out:
# 1: Missing index
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# Name: Horsepower, dtype: bool
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 32   25.0          4          98.0         NaN  2046.0          19.0
# 126  21.0          6         200.0         NaN  2875.0          17.0
# 330  40.9          4          85.0         NaN  1835.0          17.3
# 336  23.6          4         140.0         NaN  2905.0          14.3
# 354  34.5          4         100.0         NaN  2320.0          15.8
# 374  23.0          4         151.0         NaN  3035.0          20.5
#
#      Model Year  Origin
# 32           71       1
# 126          74       1
# 330          80       2
# 336          80       1
# 354          81       2
# 374          82       1

# %%
print("2: 평균으로 누락된 항목을 대체하기")
print("mpg_df['Horsepower'].mean() = ", mpg_df['Horsepower'].mean())
mpg_df.fillna(mpg_df['Horsepower'].mean(), inplace=True)
mpg_df[missing_index]
# origin을 삭제하기
mpg_df.drop('Origin', axis=1, inplace=True)
# Out:
# 2: 평균으로 누락된 항목을 대체하기
# mpg_df['Horsepower'].mean() =  104.46938775510205

# %% [markdown]
# #### (2) 각 특징들과 mpg(정답값)사이의 상관계수를 구하고, Seaborn(SNS) 히트맵을 그려라.

# %%
import seaborn as sns # 시각화: Seaborn 라이브러리
correlation_matrix = mpg_df.corr()

sns.set(rc={'figure.figsize':(12,10)})
correlation_matrix=mpg_df.corr().round(2)

mpg_corr = correlation_matrix['MPG'].abs().sort_values(ascending=False)
sorted_correlation = correlation_matrix.loc[mpg_corr.index, mpg_corr.index]

sns.heatmap(data=correlation_matrix,annot=True)

plt.show()

# %% [markdown]
# #### (3) 상관계수가 가장 높은 순서로 특징을 x1, x2, ..., x6이라고 할 때,
# 특징1개(x1)만을 사용해서 선형회귀를 한 R2 score  S1을 구하라.
# 특징2개(x1, x2)를 사용해서 선형회귀를 한 R2 score   S2을 구하라.
# 이런 식으로 특징 6개를 사용한 s6를  구하라.
# 가로축은 특징의 개수, 세로축은 S1, ..., s6인 그래프를 그려라.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

mpg_corr = correlation_matrix['MPG'].abs().sort_values(ascending=False)
features_sorted = mpg_corr.index[1:].tolist()

print("상관계수 순서:", features_sorted)

y = mpg_df['MPG']
X = mpg_df[features_sorted]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

r2_scores = []
for i in range(1, len(features_sorted) + 1):
    selected_features = features_sorted[:i]
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]

    model = LinearRegression()
    model.fit(X_train_selected, y_train)
    y_pred = model.predict(X_test_selected)

    r2 = r2_score(y_test, y_pred)
    r2_scores.append(r2)
    print(f"특징 {i}개 ({selected_features}): R2 = {r2:.4f}")

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(features_sorted) + 1), r2_scores, marker='o', linewidth=2, markersize=8)
plt.xlabel('Number of Features', fontsize=12)
plt.ylabel('R2 Score', fontsize=12)
plt.grid(True, alpha=0.3)
plt.xticks(range(1, len(features_sorted) + 1))
plt.tight_layout()
plt.show()

# train_test_split()는 random하게 학습/테스트데이터를 선택하므로, 아래의 그래프는 계속 달라질 수 있음. 경향은 비슷해야 함.
# Out:
# 상관계수 순서: ['Weight', 'Displacement', 'Cylinders', 'Horsepower', 'Model\xa0Year', 'Acceleration']
# 특징 1개 (['Weight']): R2 = 0.7332
# 특징 2개 (['Weight', 'Displacement']): R2 = 0.7440
# 특징 3개 (['Weight', 'Displacement', 'Cylinders']): R2 = 0.7429
# 특징 4개 (['Weight', 'Displacement', 'Cylinders', 'Horsepower']): R2 = 0.7491
# 특징 5개 (['Weight', 'Displacement', 'Cylinders', 'Horsepower', 'Model\xa0Year']): R2 = 0.8259
# 특징 6개 (['Weight', 'Displacement', 'Cylinders', 'Horsepower', 'Model\xa0Year', 'Acceleration']): R2 = 0.8266

# %% [markdown]
#   (1) $R^2$ score를 설명하라.  (ipynb 파일내에서 text(or markdown)로 설명함)
#
#   설명을 적을 것

# %% [markdown]
# #### (4) 특징을 6개 사용한 경우에 대해 Test dataset에 대해  정답값과 예측치간의 MSE를 구하기
# train_test_split의 random_state는 42로 하라.

# %%
mpg_df.columns[6]
# Out:
# 'Model\xa0Year'

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

df_x_data = mpg_df.drop('MPG',axis=1)
df_y_data = mpg_df['MPG']
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, random_state = 42, train_size=0.7)

linear_reg = LinearRegression().fit(X_train, y_train)
y_test_pred = linear_reg.predict(X_test)
print('MSE = ', mean_squared_error(y_test, y_test_pred))
# Out:
# MSE =  9.989386125577944

# %% [markdown]
# #### (5) 특징을 6개 사용한 경우 x축은 정답값, y축은 예측치인 그래프를 그려라.
#
# ---
#
#
#
# ---

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False
selected_features = ['Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model\xa0Year']
X = mpg_df[selected_features]
y = mpg_df['MPG']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
model = LinearRegression()
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print(f"훈련 데이터 R² score: {r2_score(y_train, y_train_pred):.4f}")
print(f"테스트 데이터 R² score: {r2_score(y_test, y_test_pred):.4f}")

# 시각화 (2개의 그래프)
plt.figure(figsize=(12, 5))

# 왼쪽-훈련 셋
plt.subplot(1, 2, 1)
plt.scatter(y_train, y_train_pred, alpha=0.7, color='red')
plt.xlabel('label')
plt.ylabel('predicted')
plt.title('Train dataset')
plt.grid(False)

# 오른쪽-테스트 셋
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred, alpha=0.7, color='green')
plt.xlabel('label')
plt.ylabel('predicted')
plt.title('Test dataset')
plt.grid(False)

plt.tight_layout()
plt.show()
# Out:
# 훈련 데이터 R² score: 0.7979
# 테스트 데이터 R² score: 0.8259
